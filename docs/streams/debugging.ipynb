# %% [markdown]
# # Debugging

# %% [markdown]
# ## Overview
#
# * [Test drive](#test_drive)
# * [Visualization](#visualization)
#   * [topology()](#topology)
#   * [mermaid()](#mermaid)

# %% [markdown]
# <a id="test_drive"></a>
# ## Test drive
