# %% [markdown]
# # Streams
#
# Welcome to the documentation the *Streams* part of *Kafi Streams*.
#
# To get started, just go to the [Quickstart](quickstart.ipynb).
#
# Learn about the architecture behind Kafi Streams in [Architecture](architecture.ipynb)
#
# The operators of Kafi Streams are explained in [Operators](operators.ipynb) - and a separate chapter is dedicated to Time Operators.
#
# How data enters Kafi Streams is laid out in Ingress, how data is processed and exits it in Processing/egress.
#
# Lifecycle elucidates how to build a Kafi Streams topology and run it.
#
# Checkpointing shows how Kafi Streams ensures fault tolerance.
#
# And to avoid bugs in the first place, Debugging is about how to test drive and visualize Kafi Streams topologies.

# %% [markdown]
# ## Overview
#
# * [Quickstart](quickstart.ipynb)
# * [Architecture](architecture.ipynb)
# * [Operators](operators.ipynb)
#   * Stateless operators
#     * map()
#     * peek()
#     * flatmap()
#     * filter()
#     * merge()
#   * Stateful operators
#     * join_equi()
#     * join()
#     * group_by_agg()
#       * group_by_sum()
#       * group_by_max()
#       * group_by_min()
#       * group_by_avg()
#       * group_by_count()
#     * agg()
#       * sum()
#       * max()
#       * min()
#       * avg()
#       * count()
#     * distinct()
#     * union()
#     * intersect()
#     * minus()
#   * Weighted operators
#     * _map()
#     * _peek()
#     * _flatmap()
#     * _filter()
#     * _neg()
#   * DBSP operators
#     * _integrate()
#     * _differentiate()
#     * _delay()
# * Time operators
#   * expire()
#   * trigger()
#   * Tumbling windows
#     * expire_tumbling()
#     * window_tumbling()
#   * Hopping windows
#     * expire_hopping()
#     * window_hopping()
#   * Cumulative windows
#     * expire_cumulative()
#     * window_cumulative()
#   * Sliding windows
#     * expire_sliding()
#     * window_sliding()
#   * Session windows
#     * expire_session()
#     * window_session()
# * Ingress and processing/egress
#   * Ingress
#     * source()
#     * push()
#       * to_zSet()
#       * from_records()
#       * from_debezium()
#       * _from_records()
#   * Processing/egress
#     * sink()
#     * latest()
#       * from_zSet()
#       * to_records()
#       * to_debezium()
#       * _to_records()
#   * process()
# * Lifecycle
#   * Building
#     * build()
#     * reset()
#   * Running
#     * start_streams()
#     * streams()
#     * streams_fun()
#     * threads()
#   * State
#     * get_state()
#     * set_state()
#     * save_state()
#     * load_state()
#     * get_state_size()
# * Checkpointing
# * Debugging and visualizing topologies
#   * Test drive
#   * Visualization
#     * topology()
#     * mermaid()
