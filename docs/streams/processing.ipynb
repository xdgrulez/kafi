# %% [markdown]
# # Processing
#
# This chapter is about the methods from `TopologyNode` which serve to get data into the stream processing engine, process it, and to get the results out.

# %% [markdown]
# ## Overview
#
# * [Sources](#sources)
#   * [source()](#source)
#   * [push()](#push)
#     * [to_zSet()](#to_zSet)
#     * [from_records()](#from_records)
#     * [from_debezium()](#from_debezium)
#     * [_from_records()](#_from_records)
# * [Processing and sinks](#processing_and_sinks)
#   * [sink()](#sink)
#   * [latest()](#latest)
#     * [from_zSet()](#from_zSet)
#     * [to_records()](#to_records)
#     * [to_debezium()](#to_debezium)
#     * [_to_records()](#_to_records)
# * [process()](#process())

# %% [markdown]
# ---
# <a id="sources"></a>
# ## Sources
